# %%
import sqlite3
import pandas as pd
import os
import shutil

# %%
def lihat_daftar_tabel(con):
    connection = sqlite3.connect(con)
    cursorObj = connection.cursor()
    cursorObj.execute('SELECT name FROM sqlite_master WHERE type= "table"')
    print(cursorObj.fetchall())

# %%
# Panggil Fungsi untuk Lihat Daftar Tabel
lihat_daftar_tabel('data_penjualan.db')
# connection.close()
# Out:
# [('orders',), ('sqlite_sequence',), ('agents',), ('customer',)]

# %%
# loading in modules
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect("data_penjualan.db")

# creating cursor
cur = con.cursor()

# reading all table names
table_list = [a for a in cur.execute("SELECT name FROM sqlite_master WHERE type = 'table'")]
# here is you table list
print(table_list)
print(cur.execute("SELECT name FROM sqlite_master WHERE type = 'table'").fetchall())

# Be sure to close the connection
con.close()
# Out:
# [('orders',), ('sqlite_sequence',), ('agents',), ('customer',)]
# [('orders',), ('sqlite_sequence',), ('agents',), ('customer',)]

# %%
# Nomor 1
# Buat Koneksi ke Database
connection = sqlite3.connect('data_penjualan.db')

# Membuat Query SQL
result  = connection.cursor()
command = "SELECT * FROM customer WHERE OPENING_AMT > 7000;"

# Eksekusi Query SQL
result.execute(command)

# Menampilkan Hasil Dalam Bentuk DataFrame
results      = result.fetchall();connection.close();
cols         = [column[0] for column in result.description]
results_data = pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#   CUST_CODE    CUST_NAME  CUST_CITY WORKING_AREA CUST_COUNTRY  GRADE  \
# 0    C00003       Martin    Torento      Torento       Canada      2
# 1    C00006      Shilton    Torento      Torento       Canada      1
# 2    C00009       Ramesh     Mumbai       Mumbai        India      3
# 3    C00014   Rangarappa  Bangalore    Bangalore        India      2
# 4    C00016   Venkatpati  Bangalore    Bangalore        India      2
# 5    C00017     Srinivas  Bangalore    Bangalore        India      2
# 6    C00019  Yearannaidu    Chennai      Chennai        India      1
#
#    OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  PHONE_NO AGENT_CODE
# 0       8000.0       7000.0       7000.0           8000.0   MJYURFD       A004
# 1      10000.0       7000.0       6000.0          11000.0   DDDDDDD       A004
# 2       8000.0       7000.0       3000.0          12000.0  Phone No       A002
# 3       8000.0      11000.0       7000.0          12000.0   AAAATGF       A001
# 4       8000.0      11000.0       7000.0          12000.0   JRTVFDD       A007
# 5       8000.0       4000.0       3000.0           9000.0   AAAAAAB       A007
# 6       8000.0       7000.0       7000.0           8000.0   ZZZZBFV       A010

# %%
# Nomor 2
# Buat Koneksi ke Database
connection = sqlite3.connect('data_penjualan.db')

# Membuat Query SQL
result  = connection.cursor()
command = """
            SELECT * FROM agents WHERE AGENT_NAME = 'Ivan';
          """

# Eksekusi Query SQL
result.execute(command)

# Menampilkan Hasil Dalam Bentuk DataFrame
results      = result.fetchall();connection.close();
cols         = [column[0] for column in result.description]
results_data = pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# c:\Users\M. ALANA\Documents\Belajar\Belajar Database\Tugas Teknikal 2_M. ALANA_Alfatih.ipynb Cell 6' in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/M.%20ALANA/Documents/Belajar/Belajar%20Database/Tugas%20Teknikal%202_M.%20ALANA_Alfatih.ipynb#ch0000004?line=10'>11</a> # Eksekusi Query SQL
#      <a href='vscode-notebook-cell:/c%3A/Users/M.%20ALANA/Documents/Belajar/Belajar%20Database/Tugas%20Teknikal%202_M.%20ALANA_Alfatih.ipynb#ch0000004?line=11'>12</a> # result.execute(command)
#      <a href='vscode-notebook-cell:/c%3A/Users/M.%20ALANA/Documents/Belajar/Belajar%20Database/Tugas%20Teknikal%202_M.%20ALANA_Alfatih.ipynb#ch0000004?line=12'>13</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/M.%20ALANA/Documents/Belajar/Belajar%20Database/Tugas%20Teknikal%202_M.%20ALANA_Alfatih.ipynb#ch0000004?line=13'>14</a> # Menampilkan Hasil Dalam Bentuk DataFrame
#      <a href='vscode-notebook-cell:/c%3A/Users/M.%20ALANA/Documents/Belajar/Belajar%20Database/Tugas%20Teknikal%202_M.%20ALANA_Alfatih.ipynb#ch0000004?line=14'>15</a> results      = result.execute(command).fetchall();connection.close();
# ---> <a href='vscode-notebook-cell:/c%3A/Users/M.%20ALANA/Documents/Belajar/Belajar%20Database/Tugas%20Teknikal%202_M.%20ALANA_Alfatih.ipynb#ch0000004?line=15'>16</a> cols         = result.execute(command).description
#      <a href='vscode-notebook-cell:/c%3A/Users/M.%20ALANA/Documents/Belajar/Belajar%20Database/Tugas%20Teknikal%202_M.%20ALANA_Alfatih.ipynb#ch0000004?line=16'>17</a> results_data = pd.DataFrame.from_records(results, columns = cols)
#      <a href='vscode-notebook-cell:/c%3A/Users/M.%20ALANA/Documents/Belajar/Belajar%20Database/Tugas%20Teknikal%202_M.%20ALANA_Alfatih.ipynb#ch0000004?line=18'>19</a> results_data
#
# ProgrammingError: Cannot operate on a closed database.

# %%
# Nomor 3 
# Buat Koneksi ke Database
connection = sqlite3.connect('data_penjualan.db')

# Membuat Query SQL
result  = connection.cursor()
command = """
            SELECT * FROM agents WHERE WORKING_AREA in ("Bangalore", "London", "Torento");
          """

# Eksekusi Query SQL
result.execute(command)

# Menampilkan Hasil Dalam Bentuk DataFrame
results      = result.fetchall();connection.close();
cols         = [column[0] for column in result.description]
results_data = pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#   AGENT_CODE  AGENT_NAME WORKING_AREA  COMMISSION      PHONE_NO COUNTRY
# 0       A001    Subbarao    Bangalore        0.14  077-12346674
# 1       A003       Alex        London        0.13  075-12458969
# 2       A004        Ivan      Torento        0.15  008-22544166
# 3       A006       McDen       London        0.15  078-22255588
# 4       A007  Ramasundar    Bangalore        0.15  077-25814763
# 5       A011  Ravi Kumar    Bangalore        0.15  077-45625874

# %%
# Nomor 4
# Buat Koneksi ke Database
connection = sqlite3.connect('data_penjualan.db')

# Membuat Query SQL
result  = connection.cursor()
command = """
            SELECT * FROM customer WHERE PAYMENT_AMT > 7000 ORDER BY OPENING_AMT DESC;
          """

# Eksekusi Query SQL
result.execute(command)

# Menampilkan Hasil Dalam Bentuk DataFrame
results      = result.fetchall();connection.close();
cols         = [column[0] for column in result.description]
results_data = pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#   CUST_CODE   CUST_NAME CUST_CITY WORKING_AREA CUST_COUNTRY  GRADE  \
# 0    C00007  Ramanathan   Chennai      Chennai        India      1
# 1    C00008    Karolina   Torento      Torento       Canada      1
# 2    C00018     Fleming   Brisban      Brisban    Australia      2
# 3    C00022     Avinash    Mumbai       Mumbai        India      2
# 4    C00002        Bolt  New York     New York          USA      3
# 5    C00012      Steven  San Jose     San Jose          USA      1
#
#    OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT      PHONE_NO  \
# 0       7000.0      11000.0       9000.0           9000.0       GHRDWSD
# 1       7000.0       7000.0       9000.0           5000.0       HJKORED
# 2       7000.0       7000.0       9000.0           5000.0       NHBGVFC
# 3       7000.0      11000.0       9000.0           9000.0  113-12345678
# 4       5000.0       7000.0       9000.0           3000.0       DDNRDRH
# 5       5000.0       7000.0       9000.0           3000.0       KRFYGJK
#
#   AGENT_CODE
# 0       A010
# 1       A004
# 2       A005
# 3       A002
# 4       A008
# 5       A012

# %%
# Nomor 5
# Buat Koneksi ke Database
connection = sqlite3.connect('data_penjualan.db')

# Membuat Query SQL
result  = connection.cursor()
command = """
            SELECT * FROM customer WHERE CUST_COUNTRY != "USA" AND GRADE > 1;
          """

# Eksekusi Query SQL
result.execute(command)

# Menampilkan Hasil Dalam Bentuk DataFrame
results      = result.fetchall();connection.close();
cols         = [column[0] for column in result.description]
results_data = pd.DataFrame.from_records(results, columns = cols)

results_data
# Out:
#    CUST_CODE   CUST_NAME  CUST_CITY WORKING_AREA CUST_COUNTRY  GRADE  \
# 0     C00003      Martin    Torento      Torento       Canada      2
# 1     C00009      Ramesh     Mumbai       Mumbai        India      3
# 2     C00010     Charles  Hampshair    Hampshair           UK      3
# 3     C00011   Sundariya    Chennai      Chennai        India      3
# 4     C00013      Holmes     London       London           UK      2
# 5     C00014  Rangarappa  Bangalore    Bangalore        India      2
# 6     C00016  Venkatpati  Bangalore    Bangalore        India      2
# 7     C00017    Srinivas  Bangalore    Bangalore        India      2
# 8     C00018     Fleming    Brisban      Brisban    Australia      2
# 9     C00022     Avinash     Mumbai       Mumbai        India      2
# 10    C00024        Cook     London       London           UK      2
# 11    C00025   Ravindran  Bangalore    Bangalore        India      2
#
#     OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT      PHONE_NO  \
# 0        8000.0       7000.0       7000.0           8000.0       MJYURFD
# 1        8000.0       7000.0       3000.0          12000.0      Phone No
# 2        6000.0       4000.0       5000.0           5000.0       MMMMMMM
# 3        7000.0      11000.0       7000.0          11000.0       PPHGRTS
# 4        6000.0       5000.0       7000.0           4000.0       BBBBBBB
# 5        8000.0      11000.0       7000.0          12000.0       AAAATGF
# 6        8000.0      11000.0       7000.0          12000.0       JRTVFDD
# 7        8000.0       4000.0       3000.0           9000.0       AAAAAAB
# 8        7000.0       7000.0       9000.0           5000.0       NHBGVFC
# 9        7000.0      11000.0       9000.0           9000.0  113-12345678
# 10       4000.0       9000.0       7000.0           6000.0       FSDDSDF
# 11       5000.0       7000.0       4000.0           8000.0       AVAVAVA
#
#    AGENT_CODE
# 0        A004
# 1        A002
# 2        A009
# 3        A010
# 4        A003
# 5        A001
# 6        A007
# 7        A007
# 8        A005
# 9        A002
# 10       A006
# 11       A011
