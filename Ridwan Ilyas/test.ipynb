# %%
import numpy as np
# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf

# load MNIST Digit data
data = tf.keras.datasets.mnist

# here data is split into 70,30 by default
(X_train, Y_train), (X_test, Y_test) = data.load_data()

# normalizing data
X_train = tf.keras.utils.normalize(X_train)
X_test = tf.keras.utils.normalize(X_test)

# checking shape of data
print(X_train.shape)
print(X_test.shape)

# function to create and compile model
def createModel(input_shape, num_classes, optimizer, loss, metrics):

    model = tf.keras.models.Sequential()  ##a feed forward model , created stack of layer on top of it
    model.add(tf.keras.layers.Input(shape=input_shape))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dense(num_classes, activation='softmax'))

    model.compile(optimizer=optimizer, loss=loss, metrics=[metrics])

    return model

# model
with tf.device('/CPU:0'):
# with tf.device('/device:GPU:0'):
    model = createModel(input_shape=(28, 28), num_classes=10, optimizer='adam',
                    loss='sparse_categorical_crossentropy',
                    metrics='accuracy')

    model.summary()

    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU'))) #print no of GPU device

    model.fit(X_train, Y_train, epochs=10, validation_split=0.1)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_8 (Dense)             (None, 64)                50240
#
#  dense_9 (Dense)             (None, 128)               8320
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 76,362
# Trainable params: 76,362
# Non-trainable params: 0
# _________________________________________________________________
# Num GPUs Available:  1
# Epoch 1/10
# 1688/1688 [==============================] - 1s 771us/step - loss: 0.2913 - accuracy: 0.9121 - val_loss: 0.1403 - val_accuracy: 0.9542
# Epoch 2/10
# 1688/1688 [==============================] - 1s 728us/step - loss: 0.1293 - accuracy: 0.9598 - val_loss: 0.1061 - val_accuracy: 0.9675
# Epoch 3/10
# 1688/1688 [==============================] - 1s 734us/step - loss: 0.0924 - accuracy: 0.9712 - val_loss: 0.0914 - val_accuracy: 0.9737
# Epoch 4/10
# 1688/1688 [==============================] - 1s 744us/step - loss: 0.0721 - accuracy: 0.9768 - val_loss: 0.0937 - val_accuracy: 0.9725
# Epoch 5/10
# 1688/1688 [==============================] - 1s 735us/step - loss: 0.0614 - accuracy: 0.9799 - val_loss: 0.0985 - val_accuracy: 0.9720
# Epoch 6/10
# 1688/1688 [==============================] - 1s 726us/step - loss: 0.0485 - accuracy: 0.9838 - val_loss: 0.0909 - val_accuracy: 0.9770
# Epoch 7/10
# 1688/1688 [==============================] - 1s 725us/step - loss: 0.0420 - accuracy: 0.9862 - val_loss: 0.1276 - val_accuracy: 0.9670
# Epoch 8/10
# 1688/1688 [==============================] - 1s 751us/step - loss: 0.0381 - accuracy: 0.9868 - val_loss: 0.1040 - val_accuracy: 0.9737
# Epoch 9/10
# 1688/1688 [==============================] - 1s 730us/step - loss: 0.0328 - accuracy: 0.9890 - val_loss: 0.0950 - val_accuracy: 0.9772
# Epoch 10/10
# 1688/1688 [==============================] - 1s 739us/step - loss: 0.0259 - accuracy: 0.9911 - val_loss: 0.1204 - val_accuracy: 0.9752
