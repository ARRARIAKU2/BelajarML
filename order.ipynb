# %%
import pandas as pd

# %%
data1 = pd.read_csv("order_items.csv")
data2 = pd.read_csv("orders.csv")

# %%
data1
# Out:
#             id  order_id  user_id  product_id  inventory_item_id      status  \
# 0        59347     41038    33153       13606             160256     Shipped
# 1       101072     69979    56200       13606             272958     Shipped
# 2        63687     44006    35515       13606             171991    Complete
# 3        16338     11275     9230       13606              44149   Cancelled
# 4        85756     59418    47846       13606             231665   Cancelled
# ...        ...       ...      ...         ...                ...         ...
# 180503  102243     70792    56851        3633             276090  Processing
# 180504  134300     92879    74538        3633             362611  Processing
# 180505  169592    117130    94127        3449             457985     Shipped
# 180506   84906     58830    47366        3449             229398    Complete
# 180507  156165    107901    86655        3449             421785  Processing
#
# ...

# %%
data2
data2
# Out:
#         order_id  user_id      status gender                 created_at  \
# 0             11        9     Shipped      F  2021-12-11 05:34:00+00:00
# 1             12        9     Shipped      F  2022-01-18 05:34:00+00:00
# 2             22       14     Shipped      F  2020-08-18 11:51:00+00:00
# 3             25       16     Shipped      F  2020-12-16 08:35:00+00:00
# 4             26       16     Shipped      F  2020-09-07 08:35:00+00:00
# ...          ...      ...         ...    ...                        ...
# 124507    124467    99958  Processing      M  2022-05-14 09:32:00+00:00
# 124508    124468    99958  Processing      M  2022-05-25 09:32:00+00:00
# 124509    124491    99980  Processing      M  2021-10-07 00:32:00+00:00
# 124510    124502    99991  Processing      M  2021-05-31 14:50:00+00:00
# 124511    124512   100000  Processing      M  2021-06-08 09:25:00+00:00
#
#        returned_at                 shipped_at delivered_at  num_of_item
# ...

# %%
data_join = pd.merge(data1, data2, how  = "outer")

data_join
data_join.to_csv("order_items_orders.csv", index = False)

# %%
data_join = data1.merge(data2, on="order_id")

data_join
# Out:
#             id  order_id  user_id_x  product_id  inventory_item_id  \
# 0        59347     41038      33153       13606             160256
# 1       101072     69979      56200       13606             272958
# 2        63687     44006      35515       13606             171991
# 3        63688     44006      35515        9347             171995
# 4        63686     44006      35515       12217             171987
# ...        ...       ...        ...         ...                ...
# 180503   25619     17713      14369         146              69136
# 180504  164245    113476      91134        3633             443676
# 180505  130651     90332      72462         146             352700
# 180506   26554     18386      14910        3633              71657
# 180507  156165    107901      86655        3449             421785
#
#           status_x                      created_at_x  \
# 0          Shipped         2020-01-05 08:14:27+00:00
# ...
